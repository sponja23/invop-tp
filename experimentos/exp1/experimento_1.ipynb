# %% [markdown]
# # Experimento 1 - Sin Restricciones Adicionales

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append("../..")

import pickle
import random

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# Use latex
plt.rc("text", usetex=True)

# %% [markdown]
# ## Generación

# %% [markdown]
# Generación de datos:

# %%
from src.generacion import (
    GeneradorInstancias,
    DistribucionIndependiente,
    DistribucionUniforme,
    DistribucionNormal,
)

random.seed(42)

# Generar instancias
N = 1000

generador = GeneradorInstancias(
    cantidad_trabajadores=DistribucionUniforme(5, 10),
    cantidad_ordenes=DistribucionUniforme(5, 20),
    parametros_ordenes=DistribucionIndependiente(
        DistribucionNormal(10000, 2000),
        DistribucionUniforme(3, 10),
    ),
)

instancias = [generador.generar_instancia() for _ in range(N)]

with open("datos/instancia.pkl", "wb") as f:
    pickle.dump(instancias, f)

# %%
from typing import List
from src.instancia import InstanciaAsignacionCuadrillas


with open("datos/instancia.pkl", "rb") as f:
    instancias: List[InstanciaAsignacionCuadrillas] = pickle.load(f)

# %% [markdown]
# ## Resolución

# %% [markdown]
# Resolución (~10m):

# %%
from tqdm import tqdm
from src.modelo import ModeloAsignacionCuadrillas
from src.solver import ConfiguracionCPLEX


soluciones = []
for instancia in tqdm(instancias):
    modelo = ModeloAsignacionCuadrillas(instancia)
    solver = modelo.armar_solver(ConfiguracionCPLEX(sin_output=True))

    objetivo, valores = solver.resolver()

    anotada = modelo.anotar_solucion(valores)

    soluciones.append((objetivo, anotada))

with open("datos/solucion.pkl", "wb") as f:
    pickle.dump(soluciones, f)

# %%
from typing import List
from src.solucion import SolucionAnotada


with open("datos/solucion.pkl", "rb") as f:
    soluciones: List[SolucionAnotada] = pickle.load(f)

# %% [markdown]
# ### Distribución de Función Objetivo

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

optimos = [obj for (obj, _) in soluciones]
sns.histplot(optimos, bins=20, ax=ax, stat="density")

ax.set_xlabel("Objetivo")
ax.set_ylabel("Frecuencia")

# Save
plt.savefig("graficos/distribucion_objetivo.pdf")

plt.show()

# %%
pd.Series(optimos).describe()
# Out:
# count     1000.000000
# mean     38078.711085
# std      17125.097866
# min          0.000000
# 25%      24923.660702
# 50%      37030.539963
# 75%      50301.188755
# max      92044.492136
# dtype: float64

# %%
(pd.Series(optimos) <= 1e-8).mean()
# Out:
# np.float64(0.001)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

proporciones_optimo = [
    obj / instancia.beneficio_maximo()
    for instancia, (obj, _) in zip(instancias, soluciones)
]
sns.histplot(proporciones_optimo, bins=20, ax=ax, stat="density")

ax.set_xlabel("Proporción")
ax.set_ylabel("Frecuencia")

# Save
plt.savefig("graficos/distribucion_proporcion_objetivo.pdf")

plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

proporciones_optimo_ajustado = [
    obj / instancia.beneficio_maximo_pagando_minimo()
    for instancia, (obj, _) in zip(instancias, soluciones)
]

sns.histplot(proporciones_optimo_ajustado, bins=20, ax=ax, stat="density")

ax.set_xlabel("Proporción")
ax.set_ylabel("Frecuencia")

# Save
plt.savefig("graficos/distribucion_proporcion_objetivo_ajustado.pdf")

plt.show()

# %%
series_poa = pd.Series(proporciones_optimo_ajustado)
series_poa.describe()
# Out:
# count    1000.000000
# mean        0.810736
# std         0.165081
# min         0.000000
# 25%         0.724596
# 50%         0.859676
# 75%         0.930936
# max         1.000000
# dtype: float64

# %%
(series_poa >= 0.9).sum()
# Out:
# np.int64(355)

# %%
((series_poa - 1).abs() < 0.000001).sum()

# %% [markdown]
# ### Distribución de Cantidad y Proporción de Órdenes

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

cantidad_ordenes = [
    solucion.cantidad_de_ordenes_realizadas() for (_, solucion) in soluciones
]

counts = pd.Series(cantidad_ordenes).value_counts()
sns.barplot(x=counts.index, y=counts.values, ax=ax)

ax.set_xlabel("Cantidad de órdenes")
ax.set_ylabel("Cantidad")

# Save
plt.savefig("graficos/distribucion_cantidad_ordenes.pdf")

plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

proporcion_ordenes = [
    len(solucion.ordenes_realizadas) / len(instancia.ordenes)
    for instancia, (_, solucion) in zip(instancias, soluciones)
]

sns.histplot(proporcion_ordenes, bins=10, ax=ax, stat="density")

ax.set_xlabel("Proporción")
ax.set_ylabel("Frecuencia")

# Save
plt.savefig("graficos/distribucion_proporcion_ordenes.pdf")

plt.show()

# %% [markdown]
# ### Beneficio Máximo de Órdenes

# %%
ordenes = [
    (orden, instancia, solucion)
    for i, (instancia, (_, solucion)) in enumerate(zip(instancias, soluciones))
    for orden in instancia.ordenes
]

df_ordenes = pd.DataFrame(
    {
        "beneficio": [orden.beneficio for orden, _, _ in ordenes],
        "cant_trab": [orden.cant_trab for orden, _, _ in ordenes],
        "beneficio_maximo": [
            orden.beneficio - 1000 * orden.cant_trab for orden, _, _ in ordenes
        ],
        "realizada": [
            orden.id in solucion.ordenes_realizadas for orden, _, solucion in ordenes
        ],
        "realizable": [
            orden.cant_trab <= instancia.cantidad_trabajadores
            for orden, instancia, _ in ordenes
        ],
    }
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

sns.histplot(
    df_ordenes,
    x="beneficio_maximo",
    bins=20,
    ax=ax,
    stat="density",
    hue="realizada",
)

ax.set_xlabel("Beneficio máximo")
ax.set_ylabel("Frecuencia")

# Save
plt.savefig("graficos/distribucion_beneficio_maximo_realizada.pdf")

plt.show()

# %%
(df_ordenes[~df_ordenes["realizada"]]["beneficio_maximo"] >= 0).mean()
# Out:
# np.float64(0.6643754909662215)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

df_ordenes_realizables = df_ordenes[df_ordenes["realizable"]]

sns.histplot(
    df_ordenes_realizables,
    x="beneficio_maximo",
    bins=20,
    ax=ax,
    stat="density",
    hue="realizada",
)

ax.set_xlabel("Beneficio máximo")
ax.set_ylabel("Frecuencia")

# Save
plt.savefig("graficos/distribucion_beneficio_maximo_realizable.pdf")

plt.show()

# %%
(
    df_ordenes_realizables[~df_ordenes_realizables["realizada"]]["beneficio_maximo"]
    >= 0
).mean()
# Out:
# np.float64(0.5121006776379478)
